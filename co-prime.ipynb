# %% [markdown]
# <a href="https://colab.research.google.com/github/iamtatha/Data_Science/blob/master/co-prime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sympy
import cv2
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
def gcd(p,q):
    while q != 0:
        p, q = q, p%q
    return p
def is_coprime(x, y):
    return gcd(x, y) == 1

# %%
n= 101

cox = []
coy = []

for i in range(n):
  for j in range(i,n):
    if is_coprime(i,j)==1:
      cox.append(i)
      coy.append(j)

# %%
len(cox)
# Out:
# 3045

# %%
fig = plt.figure(figsize=(120,100))

for i in range(len(cox)):
  plt.scatter(cox[i],coy[i],s=100)

# %%
fig = plt.figure(figsize=(120,100))

for i in range(len(cox)):
  x = math.sqrt((cox[i]**2)+(coy[i]**2))
  try:
    y = math.atan(coy[i]/cox[i])
  except ZeroDivisionError:
    y = math.pi/2
  
  plt.scatter(x,y,s=100)

# %%
fig = plt.figure(figsize=(120,100))

for i in range(len(cox)):
  x = cox[i]*math.cos(coy[i])
  y = cox[i]*math.sin(coy[i])
  
  plt.scatter(x,y,s=100)
